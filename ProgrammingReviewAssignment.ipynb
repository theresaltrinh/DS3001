# %%
! git clone https://www.github.com/DS3001/programming
# Out:
# Cloning into 'programming'...
# ...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 28 (delta 6), reused 10 (delta 5), pack-reused 16
# Receiving objects: 100% (28/28), 1.10 MiB | 12.01 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %% [markdown]
# # Question 1
#
# ![Screenshot 2024-01-22 at 6.15.43 PM.png](data:image/png;base64,...)
#
# Based on my findings, I was the most surprised to see that the number of jobs was so low (10,000) compared to the other jobs that I had looked at. With the recent COVID-19 pandemic in 2020 and a continued focus on infectious diseases, I thought that there would be a greater number of epidemiologist jobs throughout the United States. Furthermore, besides data scientists with a job outlook of 35%, epidemiologists had the 2nd highest job outlook of 27%. I'm curious to see how many more jobs will open up for epidemiologists within the next few years.
#
# Rankings (best to worst): Physicians and Surgeons > Lawyers > Pharmacists > Dentists > Data Scientist > Biomedical Engineer > Epidemiologists > Community Health Workers
#
# *   These rankings were made based off salary as well as number of jobs. I noticed that the jobs with higher salaries tended to have a greater number of jobs available compared to those of lower salary.

# %% [markdown]
# # Question 2

# %%
import numpy as np
import matplotlib.pyplot as plt

# Plot 1
x = np.linspace(0,1,50)
y = np.log(x)
z = np.exp(x)
plt.scatter(x,y)
plt.scatter(x,z)
plt.show()

x = np.linspace(0,1,50)
y = np.log(x)
z = np.exp(x)
plt.scatter(x,y, label ='Natural Log')
plt.scatter(x,z, label='Exponential')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend(loc='lower right')
plt.title('Natural Log and Exponential Functions')
plt.show()

# Plot 2
x = np.linspace(-6.5,6.5,100)
y = np.sin(x)
z = np.cos(x)
plt.scatter(x,y)
plt.scatter(x,z)
plt.show()

x = np.linspace(-6.5,6.5,100)
y = np.sin(x)
z = np.cos(x)
plt.plot(x,y, label ='Sine')
plt.plot(x,z, label='Cosine')
plt.show()

x = np.linspace(-6.5,6.5,100)
y = np.sin(x)
z = np.cos(x)
plt.plot(x,y, label ='Sine')
plt.plot(x,z, label='Cosine')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend(loc='lower left')
plt.title('Sine and Cosine')
plt.show()
# Out:
# <ipython-input-2-ba1588f736f6>:6: RuntimeWarning: divide by zero encountered in log
#   y = np.log(x)
# <ipython-input-2-ba1588f736f6>:13: RuntimeWarning: divide by zero encountered in log
#   y = np.log(x)
